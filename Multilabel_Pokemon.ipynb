# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
from ydata_profiling import ProfileReport
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.tree import DecisionTreeClassifier

# %%
path = 'pokemons.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#              Nome              Tipo               Habilidades   Geração
# 0       Bulbasaur  Planta, Venenoso  Raio Solar, Veneno Ácido  Primeira
# 1         Ivysaur  Planta, Venenoso  Raio Solar, Veneno Ácido  Primeira
# 2        Venusaur  Planta, Venenoso  Raio Solar, Veneno Ácido  Primeira
# 3      Charmander              Fogo  Chama, Investida de Fogo  Primeira
# 4      Charmeleon              Fogo  Chama, Investida de Fogo  Primeira
# ...           ...               ...                       ...       ...
# 1242      Cursola          Fantasma    Bola Sombria, Confusão    Oitava
# 1243    Runerigus   Fantasma, Terra   Bola Sombria, Terremoto    Oitava
# 1244  Stonjourner             Rocha   Pedra Afiada, Investida    Oitava
# 1245       Eiscue              Gelo     Raio de Gelo, Tumulto    Oitava
# 1246     Indeedee  Psíquico, Normal          Confusão, Desejo    Oitava
#
# [1247 rows x 4 columns]

# %%
df.head()
# Out:
#          Nome              Tipo               Habilidades   Geração
# 0   Bulbasaur  Planta, Venenoso  Raio Solar, Veneno Ácido  Primeira
# 1     Ivysaur  Planta, Venenoso  Raio Solar, Veneno Ácido  Primeira
# 2    Venusaur  Planta, Venenoso  Raio Solar, Veneno Ácido  Primeira
# 3  Charmander              Fogo  Chama, Investida de Fogo  Primeira
# 4  Charmeleon              Fogo  Chama, Investida de Fogo  Primeira

# %%
profile = ProfileReport(df, title = 'Pokemon data-base', explorative = True)
profile.to_file('pokemon_report.html')
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
df.drop_duplicates(inplace = True)

# %%
df[df['Nome'] == 'Indeedee']
# Out:
#           Nome              Tipo          Habilidades Geração
# 803   Indeedee  Psíquico, Normal  Confusão, Investida  Quarta
# 1145  Indeedee  Psíquico, Normal     Confusão, Desejo  Oitava

# %%
df.isnull().sum()
# Out:
# Nome           0
# Tipo           0
# Habilidades    0
# Geração        0
# dtype: int64

# %%
df['Tipo'].value_counts()
# Out:
# Tipo
# Água                 78
# Normal               78
# Planta               56
# Psíquico             49
# Fogo                 40
#                      ..
# Noturno, Normal       1
# Psíquico, Gelo        1
# Elétrico, Sombrio     1
# Elétrico, Dragão      1
# Voador, Aço           1
# Name: count, Length: 209, dtype: int64

# %%
grafico = px.treemap(df, path =['Tipo'])
grafico

# %%
grafico = px.treemap(df,  path = ['Geração','Tipo','Nome'])
grafico

# %%
grafico = px.treemap(df, path = [ 'Tipo', 'Habilidades'])
grafico

# %%
mlb = MultiLabelBinarizer()

# %%
x = mlb.fit_transform(df['Habilidades'].str.split(', '))
y = mlb.classes_

# %%
x_train, x_test, y_train, y_test = train_test_split(x, df['Tipo'], test_size = 0.3, random_state = 42)

# %%
model = DecisionTreeClassifier(random_state= 42)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
previsoes = model.predict(x_test)
previsoes
# Out:
# array(['Normal, Voador', 'Gelo, Terrestre', 'Aço, Fantasma',
#        'Fantasma, Fogo', 'Normal, Fada', 'Noturno, Psíquico',
#        'Planta, Venenoso', 'Normal', 'Fogo', 'Normal', 'Fada', 'Fantasma',
#        'Inseto', 'Aço, Fada', 'Venenoso', 'Fantasma', 'Água, Terrestre',
#        'Rocha', 'Inseto', 'Elétrico', 'Normal, Voador', 'Fogo',
#        'Pedra, Voador', 'Água', 'Inseto, Elétrico', 'Aço, Fantasma',
#        'Água', 'Psíquico', 'Inseto, Rocha', 'Lutador', 'Elétrico', 'Gelo',
#        'Normal', 'Elétrico', 'Fogo, Sombrio', 'Rocha, Psíquico', 'Terra',
#        'Normal, Voador', 'Terrestre', 'Água', 'Fogo', 'Água',
#        'Inseto, Elétrico', 'Planta, Psíquico', 'Normal, Voador', 'Planta',
#        'Inseto', 'Normal', 'Fogo', 'Inseto', 'Água, Gelo',
#        'Lutador, Fantasma', 'Lutador', 'Sombrio, Metal', 'Água, Elétrico',
#        'Normal', 'Gelo', 'Fantasma', 'Terrestre', 'Normal, Psíquico',
#        'Terrestre', 'Planta', 'Noturno', 'Normal, Voador', 'Normal',
#        'Água, Noturno', 'Planta', 'Inseto', 'Água', 'Planta', 'Gelo',
#        'Planta', 'Normal, Voador', 'Dragão, Fantasma', 'Normal, Voador',
#        'Planta', 'Água, Inseto', 'Água, Lutador', 'Elétrico', 'Normal',
#        'Venenoso', 'Lutador, Psíquico', 'Fantasma', 'Água, Voador',
#        'Fogo', 'Fantasma', 'Fogo, Psíquico', 'Planta', 'Fogo, Voador',
#        'Elétrico', 'Lutador', 'Planta, Venenoso', 'Normal',
#        'Normal, Voador', 'Inseto, Metal', 'Aço', 'Água, Inseto',
#        'Sombrio, Voador', 'Água, Gelo', 'Elétrico', 'Planta', 'Normal',
#        'Metal', 'Normal', 'Fogo, Metal', 'Inseto, Elétrico',
#        'Dragão, Fogo', 'Planta', 'Água, Dragão', 'Água, Noturno', 'Fogo',
#        'Sombrio, Voador', 'Normal', 'Elétrico', 'Planta, Dragão', 'Água',
#        'Água', 'Pedra, Água', 'Lutador', 'Planta', 'Lutador', 'Dragão',
#        'Planta, Venenoso', 'Normal', 'Fogo', 'Lutador', 'Lutador',
#        'Dragão', 'Água, Rocha', 'Água, Voador', 'Lutador', 'Psíquico',
#        'Inseto', 'Normal, Voador', 'Normal', 'Inseto', 'Sombrio, Voador',
#        'Inseto', 'Normal', 'Psíquico', 'Fantasma', 'Inseto, Venenoso',
#        'Fogo, Terrestre', 'Dragão, Fantasma', 'Lutador', 'Normal, Voador',
#        'Fantasma', 'Psíquico', 'Fogo', 'Água, Terrestre', 'Venenoso',
#        'Psíquico', 'Água, Planta', 'Terra', 'Psíquico', 'Planta',
#        'Dragão, Psíquico', 'Fantasma', 'Inseto', 'Normal',
#        'Lutador, Gelo', 'Dragão, Elétrico', 'Inseto, Venenoso', 'Dragão',
#        'Água, Gelo', 'Normal, Voador', 'Água', 'Psíquico', 'Psíquico',
#        'Gelo', 'Metal, Psíquico', 'Planta', 'Inseto', 'Fantasma, Planta',
#        'Normal', 'Planta, Venenoso', 'Terrestre, Noturno', 'Dragão',
#        'Terrestre', 'Rocha', 'Lutador, Fantasma', 'Lutador',
#        'Normal, Voador', 'Dragão, Elétrico', 'Água, Rocha',
#        'Fantasma, Planta', 'Fantasma, Planta', 'Água', 'Elétrico',
#        'Lutador', 'Lutador', 'Fantasma, Planta', 'Venenoso, Terra',
#        'Fogo, Psíquico', 'Normal, Voador', 'Água, Psíquico', 'Água',
#        'Inseto, Rocha', 'Água, Inseto', 'Fogo, Inseto',
#        'Planta, Venenoso', 'Psíquico, Voador', 'Fantasma, Planta',
#        'Noturno', 'Inseto, Metal', 'Água', 'Noturno', 'Elétrico', 'Fogo',
#        'Dragão', 'Pedra, Água', 'Normal', 'Água, Inseto', 'Fada',
#        'Psíquico', 'Rocha', 'Água, Inseto', 'Fantasma, Planta',
#        'Água, Terrestre', 'Pedra, Água', 'Metal, Psíquico', 'Elétrico',
#        'Normal', 'Água, Inseto', 'Normal', 'Fogo', 'Fogo',
#        'Inseto, Venenoso', 'Normal, Psíquico', 'Planta, Venenoso',
#        'Venenoso', 'Fogo', 'Dragão', 'Fogo', 'Fantasma', 'Voador, Dragão',
#        'Normal, Psíquico', 'Rocha', 'Fada', 'Elétrico', 'Metal',
#        'Pedra, Fada', 'Aço, Fada', 'Terrestre', 'Gelo', 'Água, Psíquico',
#        'Fantasma, Terrestre', 'Fada', 'Água', 'Aço', 'Elétrico', 'Normal',
#        'Inseto', 'Dragão', 'Elétrico', 'Planta', 'Normal, Fada',
#        'Venenoso, Terra', 'Elétrico', 'Normal', 'Fada', 'Elétrico',
#        'Dragão', 'Fogo', 'Pedra, Voador', 'Pedra, Gelo', 'Fada',
#        'Fantasma', 'Planta, Venenoso', 'Inseto', 'Água', 'Pedra, Voador',
#        'Elétrico', 'Lutador', 'Gelo, Planta', 'Normal', 'Lutador',
#        'Normal, Voador', 'Pedra, Planta', 'Água', 'Fogo, Sombrio',
#        'Elétrico, Voador', 'Normal, Voador', 'Gelo, Inseto',
#        'Normal, Voador', 'Lutador', 'Lutador', 'Terra', 'Inseto',
#        'Inseto, Venenoso', 'Fantasma', 'Dragão', 'Água', 'Fogo', 'Fogo',
#        'Sombrio, Voador', 'Lutador, Voador', 'Psíquico', 'Normal, Voador',
#        'Inseto, Elétrico', 'Normal, Voador', 'Fantasma, Terrestre',
#        'Inseto', 'Rocha', 'Planta', 'Pedra, Voador', 'Gelo', 'Rocha',
#        'Planta, Venenoso', 'Água', 'Normal, Voador', 'Noturno',
#        'Normal, Voador', 'Normal', 'Fogo, Sombrio', 'Terra',
#        'Fogo, Sombrio', 'Sombrio, Voador', 'Dragão, Voador',
#        'Água, Terra', 'Água, Terra', 'Planta', 'Normal, Voador',
#        'Lutador', 'Lutador', 'Gelo', 'Fogo, Lutador', 'Normal, Fada',
#        'Elétrico', 'Fantasma', 'Inseto, Venenoso', 'Água, Noturno',
#        'Lutador', 'Lutador', 'Noturno, Fantasma', 'Lutador',
#        'Água, Psíquico', 'Lutador', 'Água, Lutador', 'Dragão, Fantasma',
#        'Água, Inseto', 'Psíquico', 'Fada', 'Sombrio, Metal', 'Lutador',
#        'Psíquico, Voador', 'Normal, Voador', 'Terra', 'Água, Inseto',
#        'Água, Rocha', 'Venenoso, Lutador', 'Venenoso, Terra'],
#       dtype=object)

# %%
y_test
# Out:
# 626        Normal, Voador
# 220       Gelo, Terrestre
# 678         Aço, Fantasma
# 930        Fantasma, Fogo
# 174                  Fada
#               ...
# 528             Terrestre
# 1074         Água, Inseto
# 394           Água, Metal
# 453     Venenoso, Lutador
# 983     Normal, Terrestre
# Name: Tipo, Length: 352, dtype: object

# %%
print(accuracy_score(y_test, previsoes))
# Out:
# 0.6306818181818182

# %%
print(classification_report(y_test, previsoes))
# Out:
#                      precision    recall  f1-score   support
#
#                 Aço       0.00      0.00      0.00         0
#         Aço, Dragão       0.00      0.00      0.00         1
#           Aço, Fada       0.00      0.00      0.00         0
#       Aço, Fantasma       0.50      1.00      0.67         1
#              Dragão       0.44      1.00      0.62         4
#    Dragão, Elétrico       0.50      1.00      0.67         1
#    Dragão, Fantasma       0.67      1.00      0.80         2
#        Dragão, Fogo       1.00      1.00      1.00         1
#       Dragão, Metal       0.00      0.00      0.00         1
#    Dragão, Psíquico       1.00      1.00      1.00         1
#   Dragão, Terrestre       0.00      0.00      0.00         1
#      Dragão, Voador       1.00      1.00      1.00         1
#            Elétrico       0.65      0.92      0.76        12
#       Elétrico, Aço       0.00      0.00      0.00         1
#    Elétrico, Dragão       0.00      0.00      0.00         1
#      Elétrico, Fada       0.00      0.00      0.00         2
#  Elétrico, Fantasma       0.00      0.00      0.00         1
#     Elétrico, Metal       0.00      0.00      0.00         1
#    Elétrico, Normal       0.00      0.00      0.00         3
# Elétrico, Terrestre       0.00      0.00      0.00         1
#    Elétrico, Voador       1.00      1.00      1.00         1
#                Fada       0.71      0.56      0.62         9
#            Fantasma       1.00      1.00      1.00        12
#    Fantasma, Dragão       0.00      0.00      0.00         1
#      Fantasma, Fada       0.00      0.00      0.00         1
#      Fantasma, Fogo       1.00      1.00      1.00         1
#     Fantasma, Metal       0.00      0.00      0.00         1
#    Fantasma, Planta       0.67      1.00      0.80         4
#     Fantasma, Terra       0.00      0.00      0.00         1
# Fantasma, Terrestre       0.50      0.50      0.50         2
#    Fantasma, Voador       0.00      0.00      0.00         2
#                Fogo       0.75      1.00      0.86        12
#        Fogo, Inseto       0.00      0.00      0.00         0
#       Fogo, Lutador       1.00      0.50      0.67         2
#         Fogo, Metal       0.00      0.00      0.00         0
#        Fogo, Normal       0.00      0.00      0.00         2
#      Fogo, Psíquico       0.50      1.00      0.67         1
#         Fogo, Rocha       0.00      0.00      0.00         1
#       Fogo, Sombrio       0.00      0.00      0.00         0
#     Fogo, Terrestre       1.00      1.00      1.00         1
#        Fogo, Voador       1.00      1.00      1.00         1
#                Gelo       0.71      0.71      0.71         7
#        Gelo, Inseto       1.00      1.00      1.00         1
#        Gelo, Planta       1.00      1.00      1.00         1
#      Gelo, Psíquico       0.00      0.00      0.00         1
#     Gelo, Terrestre       1.00      1.00      1.00         1
#          Gelo, Água       0.00      0.00      0.00         2
#              Inseto       0.29      0.67      0.40         6
#    Inseto, Elétrico       0.25      1.00      0.40         1
#    Inseto, Fantasma       0.00      0.00      0.00         1
#     Inseto, Lutador       0.00      0.00      0.00         2
#       Inseto, Metal       0.00      0.00      0.00         3
#      Inseto, Planta       0.00      0.00      0.00         2
#       Inseto, Rocha       0.50      1.00      0.67         1
#   Inseto, Terrestre       0.00      0.00      0.00         1
#    Inseto, Venenoso       0.40      0.33      0.36         6
#      Inseto, Voador       0.00      0.00      0.00         5
#             Lutador       0.78      0.90      0.84        20
#        Lutador, Aço       0.00      0.00      0.00         1
#   Lutador, Fantasma       0.00      0.00      0.00         0
#       Lutador, Gelo       1.00      1.00      1.00         1
#   Lutador, Psíquico       1.00      1.00      1.00         1
#     Lutador, Voador       1.00      1.00      1.00         1
#               Metal       0.50      0.50      0.50         2
#       Metal, Planta       0.00      0.00      0.00         3
#     Metal, Psíquico       0.50      1.00      0.67         1
#              Normal       0.87      0.87      0.87        23
#        Normal, Fada       0.33      1.00      0.50         1
#     Normal, Lutador       0.00      0.00      0.00         1
#      Normal, Planta       0.00      0.00      0.00         1
#    Normal, Psíquico       1.00      1.00      1.00         3
#   Normal, Terrestre       0.00      0.00      0.00         1
#      Normal, Voador       0.64      1.00      0.78        14
#             Noturno       0.25      0.33      0.29         3
#       Noturno, Fada       0.00      0.00      0.00         3
#   Noturno, Fantasma       0.00      0.00      0.00         0
#       Noturno, Fogo       0.00      0.00      0.00         1
#     Noturno, Normal       0.00      0.00      0.00         1
#   Noturno, Psíquico       0.00      0.00      0.00         0
#     Noturno, Voador       0.00      0.00      0.00         4
#               Pedra       0.00      0.00      0.00         3
#       Pedra, Dragão       0.00      0.00      0.00         1
#         Pedra, Fada       1.00      0.33      0.50         3
#         Pedra, Gelo       0.00      0.00      0.00         0
#      Pedra, Noturno       0.00      0.00      0.00         1
#       Pedra, Planta       1.00      1.00      1.00         1
#       Pedra, Voador       0.00      0.00      0.00         0
#         Pedra, Água       1.00      0.75      0.86         4
#              Planta       0.53      1.00      0.70         8
#      Planta, Dragão       1.00      1.00      1.00         1
#        Planta, Fada       0.00      0.00      0.00         1
#    Planta, Fantasma       0.00      0.00      0.00         1
#     Planta, Noturno       0.00      0.00      0.00         3
#    Planta, Psíquico       1.00      1.00      1.00         1
#    Planta, Venenoso       0.75      0.86      0.80         7
#      Planta, Voador       0.00      0.00      0.00         1
#            Psíquico       0.91      1.00      0.95        10
#      Psíquico, Fada       0.00      0.00      0.00         1
#      Psíquico, Fogo       0.00      0.00      0.00         1
#      Psíquico, Gelo       0.00      0.00      0.00         1
#    Psíquico, Voador       1.00      1.00      1.00         2
#               Rocha       0.50      1.00      0.67         3
#        Rocha, Metal       0.00      0.00      0.00         2
#     Rocha, Psíquico       1.00      1.00      1.00         1
#       Rocha, Voador       0.00      0.00      0.00         1
#      Solo, Psíquico       0.00      0.00      0.00         1
#             Sombrio       0.00      0.00      0.00         2
#      Sombrio, Metal       0.00      0.00      0.00         0
#   Sombrio, Psíquico       0.00      0.00      0.00         1
#     Sombrio, Voador       0.20      1.00      0.33         1
#               Terra       0.40      0.67      0.50         3
#           Terrestre       0.40      0.40      0.40         5
#   Terrestre, Dragão       0.00      0.00      0.00         1
# Terrestre, Fantasma       0.00      0.00      0.00         1
#    Terrestre, Metal       0.00      0.00      0.00         1
#  Terrestre, Noturno       1.00      1.00      1.00         1
#  Terrestre, Sombrio       0.00      0.00      0.00         1
#   Terrestre, Voador       0.00      0.00      0.00         2
#        Veneno, Fogo       0.00      0.00      0.00         1
#        Veneno, Água       0.00      0.00      0.00         1
#            Venenoso       0.75      0.60      0.67         5
#    Venenoso, Dragão       0.00      0.00      0.00         1
#   Venenoso, Lutador       1.00      1.00      1.00         1
#   Venenoso, Noturno       0.00      0.00      0.00         1
#     Venenoso, Terra       0.33      1.00      0.50         1
#    Venenoso, Voador       0.00      0.00      0.00         1
#      Voador, Dragão       0.00      0.00      0.00         2
#        Voador, Água       0.00      0.00      0.00         1
#                Água       1.00      0.94      0.97        17
#        Água, Dragão       1.00      1.00      1.00         1
#      Água, Elétrico       1.00      1.00      1.00         1
#          Água, Gelo       0.33      1.00      0.50         1
#        Água, Inseto       0.50      1.00      0.67         4
#       Água, Lutador       0.50      1.00      0.67         1
#         Água, Metal       0.00      0.00      0.00         1
#       Água, Noturno       0.33      0.50      0.40         2
#         Água, Pedra       0.00      0.00      0.00         1
#        Água, Planta       1.00      1.00      1.00         1
#      Água, Psíquico       1.00      1.00      1.00         3
#         Água, Rocha       0.00      0.00      0.00         0
#         Água, Terra       0.50      1.00      0.67         1
#     Água, Terrestre       1.00      1.00      1.00         3
#      Água, Venenoso       0.00      0.00      0.00         3
#        Água, Voador       0.50      1.00      0.67         1
#
#            accuracy                           0.63       352
#           macro avg       0.35      0.42      0.37       352
#        weighted avg       0.54      0.63      0.57       352
# c:\Users\Suporte\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\Suporte\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\Suporte\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\Suporte\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\Suporte\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\Suporte\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.

# %%
grafico = px.treemap(df, path = [y_test, previsoes])
grafico
